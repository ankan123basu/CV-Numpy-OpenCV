# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('D:\ComputerVision\images\pexels-photo-1108099.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img2 = cv2.imread('wrong/path/doesnot/jiuhhng.jpeg')

# %%
type(img2)
# Out:
# NoneType

# %%
img
# Out:
# array([[[ 56,  95,  74],
#         [ 56,  95,  74],
#         [ 56,  95,  74],
#         ...,
#         [ 55,  93,  71],
#         [ 55,  93,  71],
#         [ 55,  93,  71]],
#
#        [[ 56,  95,  74],
#         [ 56,  95,  74],
#         [ 56,  95,  74],
#         ...,
#         [ 55,  93,  71],
#         [ 55,  93,  71],
#         [ 55,  93,  71]],
#
#        [[ 56,  95,  74],
#         [ 56,  95,  74],
#         [ 56,  95,  74],
#         ...,
#         [ 55,  93,  71],
#         [ 55,  93,  71],
#         [ 55,  93,  71]],
#
#        ...,
#
#        [[ 54,  88,  81],
#         [ 54,  88,  81],
#         [ 54,  88,  81],
#         ...,
#         [ 50,  97, 125],
#         [ 50,  97, 125],
#         [ 50,  97, 125]],
#
#        [[ 54,  88,  81],
#         [ 54,  88,  81],
#         [ 54,  88,  81],
#         ...,
#         [ 50,  96, 127],
#         [ 50,  96, 127],
#         [ 50,  96, 127]],
#
#        [[ 54,  88,  81],
#         [ 54,  88,  81],
#         [ 54,  88,  81],
# ...

# %%
img.shape
# Out:
# (3888, 5184, 3)

# %%
plt.imshow(img)

# %%
#MATPLOTLIB --> RGB  RED GREEN BLUE
#OPENCV --> BGR  BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
# Reading an image in grayscale
img_gray = cv2.imread('D:\ComputerVision\images\pexels-photo-1108099.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (3888, 5184)

# %%
img_gray.min()
# Out:
# np.uint8(19)

# %%
img_gray.max()
# Out:
# np.uint8(228)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')  # Example of using a different colormap

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (3888, 5184, 3)

# %%
new_img = cv2.resize(fix_img, (2500, 1200))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8  # 80% of the original width
h_ratio = 0.2 # 20% of the original height

# %%
new1_img = cv2.resize(fix_img,(0,0),fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new1_img)

# %%
new1_img.shape
# Out:
# (778, 4147, 3)

# %%
new2_img = cv2.flip(fix_img, 0) # Flip vertically
plt.imshow(new2_img)

# %%
new2_img = cv2.flip(fix_img, 1)  # Flip horizontally
plt.imshow(new2_img)

# %%
new2_img = cv2.flip(fix_img, -1)  # Flip both vertically and horizontally
plt.imshow(new2_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('D:\\ComputerVision\\images\\totally_new.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
