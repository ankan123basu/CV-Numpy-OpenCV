# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# PIL is a Python Imaging Library that adds image processing capabilities to your Python interpreter.
from PIL import Image

# %%
pic = Image.open('D:\ComputerVision\images\pexels-photo-1108099.jpeg')

# %%
# pic

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (3888, 5184, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (3888, 5184, 3)

# %%
# R G B
plt.imshow(pic_red[:,:,0])

# %%
pic_red[:,:,0]
# Out:
# array([[ 74,  74,  74, ...,  71,  71,  71],
#        [ 74,  74,  74, ...,  71,  71,  71],
#        [ 74,  74,  74, ...,  71,  71,  71],
#        ...,
#        [ 81,  81,  81, ..., 125, 125, 125],
#        [ 81,  81,  81, ..., 127, 127, 127],
#        [ 81,  81,  81, ..., 127, 127, 127]],
#       shape=(3888, 5184), dtype=uint8)

# %%
# R G B as 0 1 2
# RED CHANNEL VALUES
# 0 : no red, pure black  255 : full pure red
plt.imshow(pic_red[:,:,0], cmap='gray') # R channel in gray scale

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
pic_red[:, :, 1] = 0 # Set green channel to 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:, :, 2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (3888, 5184, 3)

# %%
pic_red[:,:,1].shape
# Out:
# (3888, 5184)
